# %% [markdown]
# <a href="https://colab.research.google.com/github/kalyani234/Drug_Project/blob/main/transformed_drugIDs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load the file to check its structure
file_path = '/content/drug_data.csv'
drug_data = pd.read_csv(file_path)

# Display the first few rows of the dataframe and its column information
drug_data.head(), drug_data.columns
# Out:
# (        id name                              interaction smile    target  \
#  0  DB00001  NaN  DB14093|DB08496|DB14055|DB01481|DB01543   NaN       NaN
#  1  DB00002  NaN  DB16077|DB00054|DB12775|DB15076|DB16376   NaN   |||||||
#  2  DB00003  NaN                                      NaN   NaN       NaN
#  3  DB00004  NaN  DB06742|DB09009|DB01086|DB06770|DB00297   NaN         |
#  4  DB00005  NaN  DB08496|DB14055|DB02806|DB01472|DB14010   NaN  ||||||||
#
#    enzyme carrier transporter
#  0    NaN     NaN         NaN
#  1    NaN     NaN         NaN
#  2    NaN     NaN         NaN
#  3    NaN     NaN         NaN
#  4    NaN     NaN         NaN  ,
#  Index(['id', 'name', 'interaction', 'smile', 'target', 'enzyme', 'carrier',
#         'transporter'],
#        dtype='object'))

# %%
# Process the data to create the desired format
# We'll split the interactions and create a new DataFrame in the specified format

# Initialize an empty list to store the transformed rows
transformed_data = []

# Iterate through each row in the original dataframe
for _, row in drug_data.iterrows():
    drug_a = row['id']
    interactions = row['interaction']

    # Check if there are interactions to process
    if pd.notna(interactions):
        # Split the interactions by '|' and create a new row for each interaction
        for drug_b in interactions.split('|'):
            transformed_data.append([drug_a, drug_b])

# Create a new DataFrame with the transformed data
transformed_df = pd.DataFrame(transformed_data, columns=['Drug A', 'Drug B'])

# Display the first few rows of the transformed data
transformed_df.head()
# Out:
#     Drug A   Drug B
# 0  DB00001  DB14093
# 1  DB00001  DB08496
# 2  DB00001  DB14055
# 3  DB00001  DB01481
# 4  DB00001  DB01543

# %%
# Save the transformed data to a CSV file
output_file_path = '/content/transformed_drug_interactions.csv'
transformed_df.to_csv(output_file_path, index=False)

output_file_path
# Out:
# '/content/transformed_drug_interactions.csv'
